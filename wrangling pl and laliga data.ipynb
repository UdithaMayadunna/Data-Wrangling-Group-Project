# %%
#load tidyverse package
library(tidyverse)

# %%
#load csv files
laliga_tables = read.csv("LaLigaTables.csv")
laliga_wages = read.csv("LaLigaWages.csv")
premier_League_table = read.csv("PremierLeagueTables.csv")
premier_league_wages = read.csv("PremierLeagueWages.csv")
summary = read.csv("summary.csv")

# %%
# inspect the structure and values of the dataset.
head(laliga_tables) 
head(laliga_wages)
# Out:
#   X Season_ID Season    League  Rk Team_ID           Squad       MP W  D ⋯
# 1 1 09/10-LL  2009-2010 La Liga 1  09/10-Barcelona   Barcelona   38 31 6 ⋯
# 2 2 09/10-LL  2009-2010 La Liga 2  09/10-Real Madrid Real Madrid 38 31 3 ⋯
# 3 3 09/10-LL  2009-2010 La Liga 3  09/10-Valencia    Valencia    38 21 8 ⋯
# 4 4 09/10-LL  2009-2010 La Liga 4  09/10-Sevilla     Sevilla     38 19 6 ⋯
# 5 5 09/10-LL  2009-2010 La Liga 5  09/10-Mallorca    Mallorca    38 18 8 ⋯
# 6 6 09/10-LL  2009-2010 La Liga 6  09/10-Getafe      Getafe      38 17 7 ⋯
#   Attendance Player_ID             Top.Team.Scorer GoalsScored Goalkeeper
# 1 77106      09/10-Lionel Messi    Lionel Messi    34          Víctor Valdés
# 2 74316      09/10-Gonzalo Higuaín Gonzalo Higuaín 27          Iker Casillas
# 3 41221      09/10-David Villa     David Villa     21          César Sánchez
# 4 38597      09/10-Luís Fabiano    Luís Fabiano    15          Andrés Palop
# ...

# %%
# See the number of unique seasons in the dataset 
unique(laliga_wages$Season)
# Out:
# [1] "2013-2014" "2014-2015" "2015-2016" "2016-2017" "2017-2018" "2018-2019"
# [7] "2019-2020" "2020-2021" "2021-2022"

# %%
# inspect the structure and values of the dataset.
head(premier_League_table)
head(premier_league_wages)
# Out:
#   X Season_ID Season    League         Rk Team_ID               Squad
# 1 1 09/10-PL  2009-2010 Premier League 1  09/10-Chelsea         Chelsea
# 2 2 09/10-PL  2009-2010 Premier League 2  09/10-Manchester Utd  Manchester Utd
# 3 3 09/10-PL  2009-2010 Premier League 3  09/10-Arsenal         Arsenal
# 4 4 09/10-PL  2009-2010 Premier League 4  09/10-Tottenham       Tottenham
# 5 5 09/10-PL  2009-2010 Premier League 5  09/10-Manchester City Manchester City
# 6 6 09/10-PL  2009-2010 Premier League 6  09/10-Aston Villa     Aston Villa
#   MP W  D  ⋯ Attendance Player_ID                Top.Team.Scorer    GoalsScored
# 1 38 27  5 ⋯ 41423      09/10-Didier Drogba      Didier Drogba      29
# 2 38 27  4 ⋯ 74864      09/10-Wayne Rooney       Wayne Rooney       26
# 3 38 23  6 ⋯ 59927      09/10-Cesc Fàbregas      Cesc Fàbregas      15
# 4 38 21  7 ⋯ 35794      09/10-Jermain Defoe      Jermain Defoe      18
# 5 38 18 13 ⋯ 45470      09/10-Carlos Tevez       Carlos Tevez       23
# ...

# %%
#filter out data to narrow it down to the required columns

laliga_tables_1 = laliga_tables %>% select(Season, Squad, W, D, L, Pts)
premier_League_table_1 = premier_League_table %>% select(Season, Squad, W, D, L, Pts)
laliga_tables_1
premier_League_table_1
# Out:
#     Season    Squad           W  D  L  Pts
# 1   2009-2010 Barcelona       31  6  1 99
# 2   2009-2010 Real Madrid     31  3  4 96
# 3   2009-2010 Valencia        21  8  9 71
# 4   2009-2010 Sevilla         19  6 13 63
# 5   2009-2010 Mallorca        18  8 12 62
# 6   2009-2010 Getafe          17  7 14 58
# 7   2009-2010 Villarreal      16  8 14 56
# 8   2009-2010 Athletic Club   15  9 14 54
# 9   2009-2010 Atlético Madrid 13  8 17 47
# 10  2009-2010 La Coruña       13  8 17 47
# 11  2009-2010 Espanyol        11 11 16 44
# 12  2009-2010 Osasuna         11 10 17 43
# 13  2009-2010 Almería         10 12 16 42
# 14  2009-2010 Zaragoza        10 11 17 41
# 15  2009-2010 Sporting Gijón   9 13 16 40
# 16  2009-2010 Racing Sant      9 12 17 39
# 17  2009-2010 Málaga           7 16 15 37
# 18  2009-2010 Valladolid       7 15 16 36
# 19  2009-2010 Tenerife         9  9 20 36
# 20  2009-2010 Xerez            8 10 20 34
# 21  2010-2011 Barcelona       30  6  2 96
# ...

# %%
# using ggplot to plot graphs and to visulaise data to see undertsand it better

laliga_tables_1[1:10,] %>%
  ggplot(aes(x = Squad, y = Pts))+
  geom_bar(stat = "identity")+
  xlab("LaLiga Season 2017-2018")+
  ylab("Points")
# Out:
# plot without title

# %%
premier_League_table_1[1:10,] %>%
  ggplot(aes(x = Squad, y = Pts))+
  geom_bar(stat = "identity")+
  guides(x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2009-2010")+
  ylab("Points")
# Out:
# plot without title

# %% [markdown]
# #### Improving the graph for better visualisation and understanding

# %%
laliga_tables_1[1:10,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .95, width = 0.6)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2009-2010")+
  ylab("Points")
# Out:
# plot without title

# %%
laliga_wages_1 = laliga_wages %>% select(Rk, Season, Team_ID,
                                         Squad, Weekly_Wages_pounds)

# %%
laliga_wages_1[1:10,] %>%
  ggplot(aes(x = Squad, y = Weekly_Wages_pounds))+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2013 - 2014")+
  ylab("Wages")
# Out:
# plot without title

# %%
#Using scales library to adjsut y axis values for better understanding of wages paid weekly
library(scales)

# %%
laliga_wages_1 = laliga_wages %>% select(Rk, Season, Team_ID,
                                         Squad, Weekly_Wages_pounds)

# %%
laliga_wages_1[1:10,] %>%
  ggplot(aes(x = Squad, y = Weekly_Wages_pounds))+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2013 - 2014")+
  ylab("Wages")
# Out:
# plot without title

# %%
#Plotting graph to understand win, loss and draw distribuition for the season 2009-2010

laliga_tables_1[1:10,] %>% select(Squad, W, D, L) %>%
  pivot_longer(cols = -Squad) %>%
  mutate(name = factor(name, levels = c("W", "D", "L")))%>%
  ggplot(aes(x = Squad, y = value, fill = name))+
  geom_col(position = position_stack(reverse = TRUE))+
  xlab("La Liga Top 10 teams season 2009 - 2010")+
  ylab("Number of games played")+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  theme_classic()
# Out:
# plot without title

# %%
premier_League_table_1 = premier_League_table %>% select(Season, Squad, W, D, L, Pts)
premier_League_table_09_10 = premier_League_table_1 %>% filter(Season == "2009-2010")

# %%
#Plotting graph to understand win, loss and draw distribuition for the season 2009-2010
premier_League_table_09_10[1:10,] %>% select(Squad, W, D, L) %>%
  pivot_longer(cols = -Squad) %>%
  mutate(name = factor(name, levels = c("W", "D", "L")))%>%
  ggplot(aes(x = Squad, y = value, fill = name))+
  geom_col(position = position_stack(reverse = TRUE))+
  xlab("Premier League Top 10 teams season 2009 - 2010")+
  ylab("Number of games played")+
  theme(axis.text=element_text(size=16),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  theme_classic()
# Out:
# plot without title

# %%
premier_League_table_1[1:10,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .95, width = 0.6)+
  theme_bw()+
  theme(axis.text=element_text( #(angle = 45, vjust = 0.5, hjust=1),
       size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2009 - 2010")+
  ylab("Points")
# Out:
# plot without title

# %%
head(laliga_wages_1)
# Out:
#   Rk Season    Team_ID               Squad           Weekly_Wages_pounds
# 1 1  2013-2014 13/14-Barcelona       Barcelona       2874391
# 2 2  2013-2014 13/14-Real Madrid     Real Madrid     2188313
# 3 3  2013-2014 13/14-Atlético Madrid Atlético Madrid  784925
# 4 4  2013-2014 13/14-Valencia        Valencia         501138
# 5 5  2013-2014 13/14-Sevilla         Sevilla          406322
# 6 6  2013-2014 13/14-Athletic Club   Athletic Club    299283

# %%
# Making tables for each season
laliga_tables_1 = laliga_tables %>% select(Season, Squad, W, D, L, Pts)
laliga_tables_15_16 = laliga_tables_1 %>% filter(Season == "2015-2016")
laliga_tables_16_17 = laliga_tables_1 %>% filter(Season == "2016-2017")
laliga_tables_17_18 = laliga_tables_1 %>% filter(Season == "2017-2018")
laliga_tables_18_19 = laliga_tables_1 %>% filter(Season == "2018-2019")
laliga_tables_19_20 = laliga_tables_1 %>% filter(Season == "2019-2020")
laliga_tables_20_21 = laliga_tables_1 %>% filter(Season == "2020-2021")
laliga_tables_21_22 = laliga_tables_1 %>% filter(Season == "2021-2022")

# %%
llt_plot_15_16 = laliga_tables_15_16[1:7,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .85, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2015-2016")+
  ylab("Points")

# %%
laliga_tables_16_17[1:7,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .85, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2016-2017")+
  ylab("Points")
# Out:
# plot without title

# %%
laliga_tables_17_18[1:7,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .85, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2017-2018")+
  ylab("Points")
# Out:
# plot without title

# %%
laliga_tables_18_19[1:7,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .85, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2018-2019")+
  ylab("Points")
# Out:
# plot without title

# %%
laliga_tables_19_20[1:7,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .85, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2019-2020")+
  ylab("Points")
# Out:
# plot without title

# %%
laliga_tables_20_21[1:7,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .85, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2020-2021")+
  ylab("Points")
# Out:
# plot without title

# %%
laliga_tables_21_22[1:7,] %>%
  mutate(name = fct_reorder(Squad, Pts))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#f68060", alpha = .85, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("LaLiga Season 2021-2022")+
  ylab("Points")
# Out:
# plot without title

# %%
# Making tables for each season

laliga_wages_15_16 = laliga_wages_1 %>% filter(Season == "2015-2016")
laliga_wages_16_17 = laliga_wages_1 %>% filter(Season == "2016-2017")
laliga_wages_17_18 = laliga_wages_1 %>% filter(Season == "2017-2018")
laliga_wages_18_19 = laliga_wages_1 %>% filter(Season == "2018-2019")
laliga_wages_19_20 = laliga_wages_1 %>% filter(Season == "2019-2020")
laliga_wages_20_21 = laliga_wages_1 %>% filter(Season == "2020-2021")
laliga_wages_21_22 = laliga_wages_1 %>% filter(Season == "2021-2022")

# %%
llw_plot_15_16 = laliga_wages_15_16[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
    guides(x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2015 - 2016")+
  ylab("Wages")
llw_plot_15_16
# Out:
# plot without title

# %%
laliga_wages_16_17[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
    guides(x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2016 - 2017")+
  ylab("Wages")
# Out:
# plot without title

# %%
laliga_wages_17_18[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
    guides(x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2017 - 2018")+
  ylab("Wages")
# Out:
# plot without title

# %%
laliga_wages_18_19[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
    guides(x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2018 - 2019")+
  ylab("Wages")
# Out:
# plot without title

# %%
laliga_wages_19_20[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
    guides(x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2019 - 2020")+
  ylab("Wages")
# Out:
# plot without title

# %%
laliga_wages_20_21[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
    guides(x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2020 - 2021")+
  ylab("Wages")
# Out:
# plot without title

# %%
laliga_wages_21_22[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_bar(stat = "identity", fill = "midnightblue", alpha = .65, width = 0.6)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
    guides(x =  guide_axis(angle = 45))+
  xlab("Laliga Wages Season 2021 - 2022")+
  ylab("Wages")
# Out:
# plot without title

# %%
# Making tables for each season

premier_League_table_1 = premier_League_table %>% select(Season, Rk, Squad, W, D, L, Pts)
pl_table_15_16 = premier_League_table_1 %>% filter(Season == "2015-2016")
pl_table_16_17 = premier_League_table_1 %>% filter(Season == "2016-2017")
pl_table_17_18 = premier_League_table_1 %>% filter(Season == "2017-2018")
pl_table_18_19 = premier_League_table_1 %>% filter(Season == "2018-2019")
pl_table_19_20 = premier_League_table_1 %>% filter(Season == "2019-2020")
pl_table_20_21 = premier_League_table_1 %>% filter(Season == "2020-2021")
pl_table_21_22 = premier_League_table_1 %>% filter(Season == "2021-2022")

# %%
pl_table_15_16[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#466964", alpha = .95, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2015-2016")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_table_16_17[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#466964", alpha = .95, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2016-2017")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_table_17_18[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#466964", alpha = .95, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2017-2018")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_table_18_19[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#466964", alpha = .95, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2018-2019")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_table_19_20[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#466964", alpha = .95, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2019-2020")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_table_20_21[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#466964", alpha = .95, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2020-2021")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_table_21_22[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Pts), Pts)+
  geom_text(aes(label = Pts), nudge_y = 3)+
  geom_col(fill = "#466964", alpha = .95, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League Season 2021-2022")+
  ylab("Points")
# Out:
# plot without title

# %%
premier_league_wages_1 = premier_league_wages %>% select(Rk, Season, Team_ID,
                                         Squad, Weekly_Wages_pounds)

# %%
# Making tables for each season

pl_wages_15_16 = premier_league_wages_1 %>% filter(Season == "2015-2016")
pl_wages_16_17 = premier_league_wages_1 %>% filter(Season == "2016-2017")
pl_wages_17_18 = premier_league_wages_1 %>% filter(Season == "2017-2018")
pl_wages_18_19 = premier_league_wages_1 %>% filter(Season == "2018-2019")
pl_wages_19_20 = premier_league_wages_1 %>% filter(Season == "2019-2020")
pl_wages_20_21 = premier_league_wages_1 %>% filter(Season == "2020-2021")
pl_wages_21_22 = premier_league_wages_1 %>% filter(Season == "2021-2022")

# %%
pl_wages_15_16[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_col(fill = "#631e50", alpha = .70, width = 0.5)+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League wages 2015-2016")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_wages_16_17[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_col(fill = "#631e50", alpha = .7, width = 0.5)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League wages 2016-2017")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_wages_17_18[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_col(fill = "#631e50", alpha = .7, width = 0.5)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League wages 2017-2018")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_wages_18_19[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_col(fill = "#631e50", alpha = .7, width = 0.5)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League wages 2018-2019")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_wages_19_20[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_col(fill = "#631e50", alpha = .7, width = 0.5)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League wages 2019-2020")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_wages_20_21[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_col(fill = "#631e50", alpha = .7, width = 0.5)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League wages 2020-2021")+
  ylab("Points")
# Out:
# plot without title

# %%
pl_wages_21_22[1:7,] %>%
  mutate(name = fct_reorder(Squad, Rk))%>%
  ggplot(aes(x = name, y = Weekly_Wages_pounds), Weekly_Wages_pounds)+
  geom_col(fill = "#631e50", alpha = .7, width = 0.5)+
  scale_y_continuous(labels = label_comma())+
  theme_bw()+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(fill=guide_legend(title="Legend"), x =  guide_axis(angle = 45))+
  xlab("Premier League wages 2021-2022")+
  ylab("Points")
# Out:
# plot without title

# %%
#Targeting only certain years fro further analysis
target_years = c("2015-2016", "2016-2017", "2017-2018", "2018-2019", "2019-2020", "2020-2021", "2021-2022")

# %%
laliga_tables_2015_2022 = laliga_tables %>% 
  select(Season, Rk, Squad, Pts, W, D, L)%>% filter(Season %in% target_years)%>%
  gather(key = "WDL", value = "Value", -c(1,2,3,4)) %>%
  ggplot(aes(x = Squad, y = Value, fill = WDL))+
  geom_col(position = position_stack())+
  theme_bw(base_size = 8.5)+
  xlab("La Liga Top 10 teams season 2015 - 2022")+
  ylab("Number of games played")
laliga_tables_2015_2022
# Out:
# plot without title

# %%
# Using gridextra to plot graphs side by side
install.packages("gridExtra")
library("gridExtra")     
grid.arrange(llt_plot_15_16, llw_plot_15_16, ncol = 2)
# Out:
# Warning message:
# "package 'gridExtra' is in use and will not be installed"
# plot without title

# %%
laliga_wages_2015_2022 = laliga_wages %>% 
  select(Season, Rk, Squad, Weekly_Wages_pounds, Annual_Wages_pounds)%>%
  filter(Season %in% target_years)

# %%
head(laliga_wages_2015_2022)
# Out:
#   Season    Rk Squad           Weekly_Wages_pounds Annual_Wages_pounds
# 1 2015-2016 1  Barcelona       2806246             145924771
# 2 2015-2016 2  Real Madrid     2439140             126835291
# 3 2015-2016 3  Atlético Madrid 1015079              52784100
# 4 2015-2016 4  Valencia         813466              42300237
# 5 2015-2016 5  Sevilla          552109              28709687
# 6 2015-2016 6  Athletic Club    398662              20730442

# %%
install.packages("hrbrthemes")
install.packages("GGally")
install.packages("viridis")
install.packages("ggthemes")
# Out:
# Warning message:
# "package 'hrbrthemes' is in use and will not be installed"
# Warning message:
# "package 'GGally' is in use and will not be installed"
# Warning message:
# "package 'viridis' is in use and will not be installed"
# Warning message:
# "package 'ggthemes' is in use and will not be installed"

# %%
#Loading additional libraries
library(hrbrthemes)
library(GGally)
library(viridis)
library(ggthemes)

# %%
#Targeting top 7 teams
target_Rk = c(1,2,3,4,5,6,7)
laliga_wages_top_7 = laliga_wages_2015_2022 %>% filter(Rk %in% target_Rk)

# %%
laliga_wages_plot = 
laliga_wages_top_7 %>%
  ggplot(aes(Season, Weekly_Wages_pounds, fill = Squad, label = Squad, color = Squad, group = Squad))+
  geom_line(size=1.5)+
  geom_point(size=3)+
  theme_bw()+
  ggtitle("Top 7 Weekly Wages of La Liga Teams (2015-2022)")+
  ylab("Weekly Wages in Pounds")+
  scale_color_viridis(discrete = TRUE)+
  theme(axis.text=element_text(size=14),
      axis.title=element_text(size=16,face="bold"))+
  guides(x =  guide_axis(angle = 45))+
  scale_y_continuous(breaks = seq(500000,6000000, by=500000), limits=c(0,6000000))
 
laliga_wages_plot
# Out:
# plot without title

# %%
#Saving the plot
ggsave(filename = "laliga_wages_plot.jpeg", 
       width = 10, height = 8, dpi = 300, units = "in", device='jpeg')

# %%
premier_league_wages_2015_2022 = premier_league_wages %>% 
  select(Season, Rk, Squad, Weekly_Wages_pounds, Annual_Wages_pounds)%>%
  filter(Season %in% target_years)

# %%
premier_league_wages_top_7 = premier_league_wages_2015_2022 %>% filter(Rk %in% target_Rk)

# %%
premier_league_wages_plot = 
premier_league_wages_top_7 %>%
  ggplot(aes(Season, Weekly_Wages_pounds, fill = Squad, label = Squad, color = Squad, group = Squad))+
  geom_line(size=1.15)+
  geom_point(size=3)+
  theme_bw(base_size =10)+
  ylab("Top 7 Weekly Wages of Premier League Teams (2015-2022)")+
  theme(axis.text=element_text(size=10),
      axis.title=element_text(size=12,face="bold"))+
  guides(x =  guide_axis(angle = 45))+
  ggtitle("Top 7 Weekly Wages of Premier League Teams (2015-2022)")+
  scale_y_continuous(breaks = seq(500000,5000000, by=500000), limits=c(0,5000000))

premier_league_wages_plot
# Out:
# plot without title

# %%
#Saving the plot
ggsave(filename = "premier_league_wages_plot.jpeg", 
       width = 10, height = 8, dpi = 300, units = "in", device='jpeg')

# %%
# LaLiga winners from 2015 to 2022
laliga_15_22 = laliga_tables %>% select(Season, Rk, Squad,Pts, Team_ID) %>% filter(Season%in%target_years, Rk %in% "1")
laliga_15_22
# Out:
#   Season    Rk Squad           Pts Team_ID
# 1 2015-2016 1  Barcelona       91  15/16-Barcelona
# 2 2016-2017 1  Real Madrid     93  16/17-Real Madrid
# 3 2017-2018 1  Barcelona       93  17/18-Barcelona
# 4 2018-2019 1  Barcelona       87  18/19-Barcelona
# 5 2019-2020 1  Real Madrid     87  19/20-Real Madrid
# 6 2020-2021 1  Atlético Madrid 86  20/21-Atlético Madrid
# 7 2021-2022 1  Real Madrid     86  21/22-Real Madrid

# %%
# Premier League winners from 2015 to 2022
premier_league_15_22 = premier_League_table %>% select(Season, Rk, Squad,Pts, Team_ID)%>% filter(Season%in%target_years, Rk %in% "1")
premier_league_15_22
# Out:
#   Season    Rk Squad           Pts Team_ID
# 1 2015-2016 1  Leicester City   81 15/16-Leicester City
# 2 2016-2017 1  Chelsea          93 16/17-Chelsea
# 3 2017-2018 1  Manchester City 100 17/18-Manchester City
# 4 2018-2019 1  Manchester City  98 18/19-Manchester City
# 5 2019-2020 1  Liverpool        99 19/20-Liverpool
# 6 2020-2021 1  Manchester City  86 20/21-Manchester City
# 7 2021-2022 1  Manchester City  93 21/22-Manchester City

# %%
premier_league_15_22_winners = 
premier_league_15_22 %>%
  ggplot(aes(x = Team_ID, y = Pts))+
  geom_bar(stat = "identity", fill = "#076fa2", width = 0.4, alpha = 0.95)+
  geom_text(aes(label = Pts), nudge_y = 5)+
  scale_y_continuous(breaks = seq(0, 120, by=20), limits=c(0,120))+
  ylab("Points")+
  xlab("")+
  theme_minimal()+
  theme(axis.text=element_text(size=10))+
  ggtitle("Premier League Season winners from 2015 to 2022")+
  coord_flip()

premier_league_15_22_winners
# Out:
# plot without title

# %%
laliga_15_22_winners = 
laliga_15_22 %>%
  ggplot(aes(x = interaction(Team_ID), y = Pts))+
  geom_bar(stat = "identity", fill = "#076fa2", width = 0.4, alpha = 0.95)+
  geom_text(aes(label = Pts), nudge_y = 5)+
  scale_y_continuous(breaks = seq(0, 110, by=20), limits=c(0,110))+
  ylab("Points")+
  xlab("")+
  theme_minimal()+
  theme(axis.text=element_text(size=14))+
  ggtitle("La Liga Season winners from 2015 to 2022")+
  coord_flip()

laliga_15_22_winners
# Out:
# plot without title

# %%
#Saving the plot
ggsave(filename = "laliga_15_22_winners.jpeg", 
       width = 10, height = 8, dpi = 300, units = "in", device='jpeg')

# %%
#Saving the plot
ggsave(filename = "premier_league_15_22_winners.jpeg", 
       width = 10, height = 8, dpi = 300, units = "in", device='jpeg')

# %%
laliga_tables_1 = laliga_tables %>% select(Season, Squad, Pts, Rk)
laliga_tables_17_22 = laliga_tables_1 %>% filter(Season%in%target_years, Rk%in%target_Rk)

# %%
#plotting teams that have finished between 2nd to 7th position for the sesons between 2015 - 2022
laliga_2_7 = laliga_tables_17_22 %>% filter(Season%in%target_years, Rk %in% c(2,3,4,5,6,7)) %>%
ggplot(aes(Season, Pts)) + 
  geom_bar(aes(fill = Squad), stat = "identity", position = "dodge")+
  ylab("Points")+
  theme_bw(base_size = 12)+
  ggtitle("Teams finishing 2nd to 7th - LaLiga")

laliga_2_7
# Out:
# plot without title

# %%
#plotting teams that have finished between 2nd to 7th position for the sesons between 2015 - 2022
pl_2_7 = premier_League_table %>% filter(Season%in%target_years, Rk %in% c(2,3,4,5,6,7)) %>%
ggplot(aes(Season, Pts)) + 
  geom_bar(aes(fill = Squad), stat = "identity", position = "dodge")+
  ylab("Points")+
  theme_bw(base_size = 12)+
  ggtitle("Teams finishing 2nd to 7th - Premier League")

pl_2_7
# Out:
# plot without title

# %%
#Saving the plot
ggsave(filename = "pl_2_7.jpeg", 
       width = 10, height = 8, dpi = 300, units = "in", device='jpeg')

# %%
#Saving the plot
ggsave(filename = "laliga_2_7.jpeg", 
       width = 10, height = 8, dpi = 300, units = "in", device='jpeg')
